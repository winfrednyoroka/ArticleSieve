# %%
# Query the PDF for full paper screening and potential data extraction

# %%
# Install necessary libraries for use

# !pip install langchain
# !pip install openai
# !pip install PyPDF2 # Read the PDF files
# !pip install faiss-cpu # store vector embeddings
# !pip install tiktoken # Creates tokens
# !pip install -U langchain-community
#!pip install -U langchain-openai
#!pip install pymupdf

# %% [markdown]
# # PyMuPDFLoader
# This is a document loader utility from the LangChain library. This is designed to work with PDF files using PyMuPDF backend. It can read and load the pdf content from PDF documents so that it canbbe processed by other applications e.g LLMs.
#
# **Use cases:** Chat with PDFs, document search, summarization
#
# **Steps**
# 1. PyMuPDF parses the PDF files.
# 2. Loads text content page by page.
# 3. Optional to split the content by page or section.
# 4. Returns the document content in a structured format that Langchain can work with.

# %%
#  Load neccesary libraries and openai key upfront
from langchain.document_loaders import PyMuPDFLoader
import pprint # pretty print - python standard library for printing data structures in a more readable and nicely formatted.
# Obtain my openai key
import os
from dotenv import load_dotenv
load_dotenv() # This works as long as the .env file is in current working directory
# Out:
# True

# %% [markdown]
# # Load PDF using PyMuPDFLoader

# %%
loader = PyMuPDFLoader('../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf')
documents = loader.load()

# Returns two file content including: Document text and metadata
for doc in documents:
     pprint.pp(f'This is the document content{doc.page_content} and this is the metadata{doc.metadata}')
# Out:
# ('This is the document contentRESEARCH ARTICLE\n'
#  'Association of maternal circulating 25(OH)D\n'
#  'and calcium with birth weight: A mendelian\n'
#  'randomisation analysis\n'
#  'William D. ThompsonID1,2, Jessica TyrrellID1, Maria-Carolina BorgesID2,3, '
#  'Robin\n'
#  'N. BeaumontID1, Bridget A. KnightID1, Andrew R. Wood1, Susan M. RingID2,3,4, '
#  'Andrew\n'
#  'T. HattersleyID1, Rachel M. Freathy1,2‡, Debbie A. LawlorID2,3,5‡*\n'
#  '1 Institute of Biomedical and Clinical Science, College of Medicine and '
#  'Health, University of Exeter, Exeter,\n'
#  'United Kingdom, 2 MRC Integrative Epidemiology Unit at the University of '
#  'Bristol, Bristol, United Kingdom,\n'
#  '3 Population Health Science, Bristol Medical School, University of Bristol, '
#  'Bristol, United Kingdom, 4 Avon\n'
#  'Longitudinal Study of Parents and Children, NIHR Bristol Biomedical Research '
#  'Centre, University of Bristol,\n'
#  'Bristol, United Kingdom, 5 Bristol NIHR Biomedical Research Centre, Bristol, '
#  'United Kingdom\n'
#  '‡ These authors are joint senior authors on this work.\n'
#  '* d.a.lawlor@bristol.ac.uk\n'
#  'Abstract\n'
#  'Background\n'
#  'Systematic reviews of randomised controlled trials (RCTs) have suggested '
#  'that maternal\n'
#  'vitamin D (25[OH]D) and calcium supplementation increase birth weight. '
#  'However, limita-\n'
#  'tions of many trials were highlighted in the reviews. Our aim was to combine '
#  'genetic and\n'
#  'RCT data to estimate causal effects of these two maternal traits on '
#  'offspring birth weight.\n'
#  'Methods and findings\n'
#  'We performed two-sample mendelian randomisation (MR) using genetic '
#  'instrumental vari-\n'
#  'ables associated with 25(OH)D and calcium that had been identified in '
#  'genome-wide asso-\n'
#  'ciation studies (GWAS; sample 1; N = 122,123 for 25[OH]D and N = 61,275 for '
#  'calcium).\n'
#  'Associations between these maternal genetic variants and offspring birth '
#  'weight were calcu-\n'
#  'lated in the UK Biobank (UKB) (sample 2; N = 190,406). We used data on '
#  'mother–child\n'
#  'pairs from two United Kingdom birth cohorts (combined N = 5,223) in '
#  'sensitivity analyses\n'
#  'to check whether results were influenced by fetal genotype, which is '
#  'correlated with the\n'
#  'maternal genotype (r \x19 0.5). Further sensitivity analyses to test the '
#  'reliability of the results\n'
#  'included MR-Egger, weighted-median estimator, ‘leave-one-out’, and '
#  'multivariable MR\n'
#  'analyses. We triangulated MR results with those from RCTs, in which we used '
#  'randomisa-\n'
#  'tion to supplementation with vitamin D (24 RCTs, combined N = 5,276) and '
#  'calcium (6\n'
#  'RCTs, combined N = 543) as an instrumental variable to determine the effects '
#  'of 25(OH)D\n'
#  'and calcium on birth weight. In the main MR analysis, there was no strong '
#  'evidence of an\n'
#  'effect of maternal 25(OH)D on birth weight (difference in mean birth weight '
#  '−0.03 g [95% CI\n'
#  '−2.48 to 2.42 g, p = 0.981] per 10% higher maternal 25[OH]D). The effect '
#  'estimate was con-\n'
#  'sistent across our MR sensitivity analyses. Instrumental variable analyses '
#  'applied to RCTs\n'
#  'suggested a weak positive causal effect (5.94 g [95% CI 2.15–9.73, p = '
#  '0.002] per 10%\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  '1 / 24\n'
#  'a1111111111\n'
#  'a1111111111\n'
#  'a1111111111\n'
#  'a1111111111\n'
#  'a1111111111\n'
#  'OPEN ACCESS\n'
#  'Citation: Thompson WD, Tyrrell J, Borges M-C,\n'
#  'Beaumont RN, Knight BA, Wood AR, et al. (2019)\n'
#  'Association of maternal circulating 25(OH)D and\n'
#  'calcium with birth weight: A mendelian\n'
#  'randomisation analysis. PLoS Med 16(6):\n'
#  'e1002828. https://doi.org/10.1371/journal.\n'
#  'pmed.1002828\n'
#  'Academic Editor: Jenny E Myers, University of\n'
#  'Manchester, UNITED KINGDOM\n'
#  'Received: October 1, 2018\n'
#  'Accepted: May 16, 2019\n'
#  'Published: June 18, 2019\n'
#  'Copyright: © 2019 Thompson et al. This is an open\n'
#  'access article distributed under the terms of the\n'
#  'Creative Commons Attribution License, which\n'
#  'permits unrestricted use, distribution, and\n'
#  'reproduction in any medium, provided the original\n'
#  'author and source are credited.\n'
#  'Data Availability Statement: Our study uses two-\n'
#  'sample mendelian randomisation (MR) and\n'
#  'instrumental variable analyses applied to RCTs. We\n'
#  'used both published summary results (i.e., taking\n'
#  'results from published research papers and\n'
#  'websites) and individual participant cohort data as\n'
#  'follows: Journal-published and website summary\n'
#  'data were used for one of the two sample MR\n'
#  '(published GWAS of circulating 25[OH]D, calcium,\n'
#  'height, and education) and also for the application\n'
#  'of instrumental variable analyses to RCTs of and this is the '
#  "metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); modified using "
#  "iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', 'creator': "
#  "'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 0}')
# ('This is the document contenthigher maternal 25[OH]D), but this result may be '
#  'exaggerated because of risk of bias in the\n'
#  'included RCTs. The main MR analysis for maternal calcium also suggested no '
#  'strong evi-\n'
#  'dence of an effect on birth weight (−20 g [95% CI −44 to 5 g, p = 0.116] per '
#  '1 SD higher\n'
#  'maternal calcium level). Some sensitivity analyses suggested that the '
#  'genetic instrument for\n'
#  'calcium was associated with birth weight via exposures that are independent '
#  'of calcium lev-\n'
#  'els (horizontal pleiotropy). Application of instrumental variable analyses '
#  'to RCTs suggested\n'
#  'that calcium has a substantial effect on birth weight (178 g [95% CI 121–236 '
#  'g, p = 1.43 ×\n'
#  '10−9] per 1 SD higher maternal calcium level) that was not consistent with '
#  'any of the MR\n'
#  'results. However, the RCT instrumental variable estimate may have been '
#  'exaggerated\n'
#  'because of risk of bias in the included RCTs. Other study limitations '
#  'include the low\n'
#  'response rate of UK Biobank, which may bias MR estimates, and the lack of '
#  'suitable data to\n'
#  'test whether the effects of genetic instruments on maternal calcium levels '
#  'during pregnancy\n'
#  'were the same as those outside of pregnancy.\n'
#  'Conclusions\n'
#  'Our results suggest that maternal circulating 25(OH)D does not influence '
#  'birth weight in oth-\n'
#  'erwise healthy newborns. However, the effect of maternal circulating calcium '
#  'on birth weight\n'
#  'is unclear and requires further exploration with more research including RCT '
#  'and/or MR\n'
#  'analyses with more valid instruments.\n'
#  'Author summary\n'
#  'Why was this study done?\n'
#  '• Birth weight that is lower or higher than average has been associated with '
#  'poor health\n'
#  'outcomes across the life span, including infant mortality, cardiovascular '
#  'disease, and\n'
#  'type 2 diabetes.\n'
#  '• If we can identify modifiable maternal factors in pregnancy that are '
#  'causally related to\n'
#  'birth weight, we may be able to reduce the number of babies that are born '
#  'with lower or\n'
#  'higher than optimal birth weight. This may in turn help to reduce the '
#  'associated poor\n'
#  'health outcomes.\n'
#  '• Previous studies have suggested that higher maternal 25(OH)D and calcium '
#  'in preg-\n'
#  'nancy are associated with higher birth weight. However, many of those '
#  'studies used\n'
#  'conventional multivariable regression in observational studies and may be '
#  'subject to\n'
#  'residual confounding. Few of them estimated the size of the effect of either '
#  'maternal\n'
#  '25(OH)D or calcium levels on birth weight.\n'
#  'What did the researchers do and find?\n'
#  '• We estimated the effects of maternal gestational 25(OH)D and calcium '
#  'levels on off-\n'
#  'spring birth weight using mendelian randomisation, a method that uses '
#  'genetic data to\n'
#  'overcome certain limitations of traditional observational studies—for '
#  'example, residual\n'
#  'confounding.\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  '2 / 24\n'
#  'vitamin D and calcium supplementation. The\n'
#  'references to those published data sources are\n'
#  'provided in the main paper. We used individual\n'
#  'participant data for the second MR sample and for\n'
#  'undertaking sensitivity analyse from the UK\n'
#  'Biobank, ALSPAC, and EFSOCH cohorts. The data\n'
#  'in UK Biobank and ALSPAC are fully available, via\n'
#  'managed systems, to any researchers. The\n'
#  'managed system for both studies is a requirement\n'
#  'of the study funders, but access is not restricted on\n'
#  'the basis of overlap with other applications to use\n'
#  'the data or on the basis of peer review of the\n'
#  'proposed science. UK Biobank: Full information on\n'
#  'how to access these data can be found here -\n'
#  'https://www.ukbiobank.ac.uk/using-the-resource/.\n'
#  'ALSPAC: The ALSPAC data management plan\n'
#  '(http://www.bristol.ac.uk/alspac/researchers/data-\n'
#  'access/documents/alspac-data-management-plan.\n'
#  'pdf) describes in detail the policy regarding data\n'
#  'sharing, which is through a system of managed\n'
#  'open access. The following steps highlight how to\n'
#  'apply for access to the data included in this paper\n'
#  'and all other ALSPAC data. (1) Please read the\n'
#  'ALSPAC access policy (PDF, 627 kB), which\n'
#  'describes the process of accessing the data and\n'
#  'samples in detail and outlines the costs associated\n'
#  'with doing so. (2) You may also find it useful to\n'
#  'browse the fully searchable ALSPAC research\n'
#  'proposals database, which lists all research\n'
#  'projects that have been approved since April 2011.\n'
#  '(3) Please submit your research proposal for\n'
#  'consideration by the ALSPAC Executive\n'
#  'Committee. You will receive a response within 10\n'
#  'working days to advise you whether your proposal\n'
#  'has been approved. If you have any questions\n'
#  'about accessing data, please email alspac-\n'
#  'data@bristol.ac.uk. EFSOCH: Requests for access\n'
#  'to the original EFSOCH dataset should be made in\n'
#  'writing in the first instance to the EFSOCH data\n'
#  'team via the Exeter Clinical Research Facility\n'
#  '(crf@exeter.ac.uk).\n'
#  'Funding: This study was supported by the US\n'
#  'National Institute of Health (R01 DK10324), the\n'
#  'European Research Council under the European\n'
#  'Union’s Seventh Framework Programme (FP7/\n'
#  '2007-2013)/ERC grant agreement no 669545, and\n'
#  'the NIHR Biomedical Centre at the University\n'
#  'Hospitals Bristol NHS Foundation Trust and the\n'
#  'University of Bristol. Core funding for ALSPAC is\n'
#  'provided by the UK Medical Research Council and\n'
#  'Wellcome (Grant ref: 102215/2/13/2) and the\n'
#  'University of Bristol. Genotyping of the ALSPAC\n'
#  'maternal samples was funded by the Wellcome\n'
#  'Trust (WT088806), and the offspring samples were\n'
#  'genotyped by Sample Logistics and Genotyping\n'
#  'Facilities at the Wellcome Trust Sanger Institute\n'
#  'and LabCorp (Laboratory Corportation of America) and this is the '
#  "metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); modified using "
#  "iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', 'creator': "
#  "'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 1}')
# ('This is the document content• We analysed genetic data on 190,406 women from '
#  'the UK Biobank who reported the\n'
#  'birth weight of their first child, along with the results from published '
#  'studies of genetic\n'
#  'associations with 25(OH)D and calcium levels in 122,123 and 61,275 '
#  'individuals,\n'
#  'respectively.\n'
#  '• We checked that the results were not biased by offspring genotype using '
#  'data from two\n'
#  'UK birth cohorts, the Avon Longitudinal Study of Parents and Children '
#  '(ALSPAC; n =\n'
#  '4,576 mother–child pairs) and Exeter Family Study of Childhood Health '
#  '(EFSOCH; n =\n'
#  '647 mother–child pairs), respectively.\n'
#  '• To strengthen our causal understanding, we triangulated the mendelian '
#  'randomisation\n'
#  'results with findings from randomised controlled trials in which we used '
#  'randomised\n'
#  'status (to vitamin D or calcium supplementation) as an instrumental variable '
#  'to esti-\n'
#  'mate the effect of 25(OH)D or calcium on birth weight.\n'
#  '• We found no evidence of a strong effect of maternal 25(OH)D on birth '
#  'weight.\n'
#  '• We found inconsistent evidence of effects of maternal calcium on birth '
#  'weight.\n'
#  'What do these findings mean?\n'
#  '• Our findings do not support using vitamin D supplementation during '
#  'pregnancy or\n'
#  'preconceptually to influence offspring birth weight.\n'
#  '• The effect of calcium on birth weight is still unclear and needs further '
#  'investigation in\n'
#  'well-powered genetic studies and/or well-conducted randomised controlled '
#  'trials.\n'
#  'Introduction\n'
#  'Infants with lower or higher birth weight (BW) than average are at an '
#  'increased risk of neona-\n'
#  'tal mortality and morbidity [1]. BW is also inversely associated with some '
#  'adverse adult health\n'
#  'outcomes, including coronary heart disease [2], type 2 diabetes [3], poor '
#  'cognitive ability [4],\n'
#  'and several types of cancer [5], with most of these associations being '
#  'linear across most of the\n'
#  'BW distribution. BW is an indicator of conditions in utero and may be '
#  'influenced by modifi-\n'
#  'able factors in the maternal circulation. For example, there is evidence '
#  'that higher maternal\n'
#  'fasting glucose is causally related to greater fetal growth and higher BW '
#  '[6,7], which increases\n'
#  'the risk of complications during delivery. However, relatively little is '
#  'known about the causal\n'
#  'influences of other maternal factors. More evidence is required on how '
#  'modifying the in utero\n'
#  'environment might influence BW and associated health outcomes.\n'
#  'Maternal gestational circulating 25(OH)D [8] and calcium [9] may be '
#  'modifiable risk fac-\n'
#  'tors that impact fetal growth and hence BW. Several observational studies '
#  'using conventional\n'
#  'multivariable regression analyses suggest positive associations of maternal '
#  '25(OH)D and cal-\n'
#  'cium with infant BW [10–13]; however, these results might be explained by '
#  'residual confound-\n'
#  'ing. Systematic reviews of randomised controlled trials (RCTs) of '
#  'gestational supplementation\n'
#  'with vitamin D [14] or calcium [15] have suggested that this supplementation '
#  'increases BW.\n'
#  'However, the authors of the latest vitamin D supplementation systematic '
#  'review concluded\n'
#  'that most of the trials were small and of low quality, and the difference in '
#  'mean BW was small\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  '3 / 24\n'
#  'using support from 23andMe. A comprehensive\n'
#  'list of grants funding is available on the ALSPAC\n'
#  'website (http://www.bristol.ac.uk/alspac/external/\n'
#  'documents/grant-acknowledgements.pdf). The\n'
#  'Exeter Family Study of Childhood Health (EFSOCH)\n'
#  'was supported by South West NHS Research and\n'
#  'Development, Exeter NHS Research and\n'
#  'Development, the Darlington Trust, and the\n'
#  'Peninsula National Institute of Health Research\n'
#  '(NIHR) Clinical Research Facility at the University\n'
#  'of Exeter. Genotyping of the EFSOCH study\n'
#  'samples was funded by Wellcome Trust and Royal\n'
#  'Society grant 104150/Z/14/Z. WDT is supported by\n'
#  'the GW4 BIOMED DTP awarded to the Universities\n'
#  'of Bath, Bristol, Cardiff and Exeter from the UK\n'
#  'Medical Research Council (MRC). M-CB is\n'
#  'supported by a UK MRC Skills Development\n'
#  'Fellowship (MR/P014054/1). RMF and RNB are\n'
#  'funded by a Wellcome Trust and Royal Society Sir\n'
#  'Henry Dale Fellowship (104150/Z/14/Z). M-CB,\n'
#  'RMF, and DAL work in/are affiliated with a unit that\n'
#  'is supported by the University of Bristol and UK\n'
#  'Medical Research Council (MC_UU_00011/6). DAL\n'
#  'is aN NIHR Senior Investigator (NF-SI-0611-\n'
#  '10196). ATH is supported by a NIHR Senior\n'
#  'Investigator award and also a Wellcome Trust\n'
#  'Senior Investigator award (098395/Z/12/Z). The\n'
#  'funders had no role in the design of the study; the\n'
#  'collection, analysis, or interpretation of the data;\n'
#  'the writing of the manuscript; or the decision to\n'
#  'submit the manuscript for publication. The views\n'
#  'expressed in this paper are those of the authors\n'
#  'and not necessarily those of any funder.\n'
#  'Competing interests: DAL has received support\n'
#  'from Medtronic LTD and Roche Diagnostics for\n'
#  'biomarker research that is not related to the study\n'
#  'presented in this paper. SMR has received funding\n'
#  'from the MRC, ESRC, and Wellcome Trust. The\n'
#  'other authors report no conflicts.\n'
#  'Abbreviations: ALSPAC, Avon Longitudinal Study\n'
#  'of Parents and Children; AMDHD1,\n'
#  'Amidohydrolase Domain Containing 1; BMD, bone\n'
#  'mineral density; BMI, body mass index; BW, birth\n'
#  'weight; CASR, calcium-sensing receptor; DHCR7,\n'
#  '7-Dehydrocholesterol reductase; EFSOCH, Exeter\n'
#  'Family Study of Childhood Health; GRM, genetic\n'
#  'relationship matrix; GWA, genome-wide\n'
#  'association; GWAS, genome-wide association\n'
#  'studies; HWE, Hardy Weinberg equilibrium; IVW,\n'
#  'inverse variance–weighted; MR, mendelian\n'
#  'randomisation; RCT, randomised controlled trial;\n'
#  'SNP, single nucleotide polymorphism; STROBE,\n'
#  'Strengthening the Reporting of Observational\n'
#  'Studies in Epidemiology; TDI, Townsend\n'
#  "deprivation index; UKB, UK Biobank. and this is the metadata{'producer': "
#  "'PDFlib+PDI 9.0.6 (C++/Win64); modified using iTextSharp™ 5.5.3 ©2000-2014 "
#  "iText Group NV (AGPL-version)', 'creator': 'Arbortext Advanced Print "
#  "Publisher 11.0.3521/W Unicode-x64', 'creationdate': "
#  "'2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 2}')
# ('This is the document contentand unlikely to be of clinical or public health '
#  'importance [16]. For the calcium supplementa-\n'
#  'tion systematic review, the authors noted that for most of the trials, there '
#  'was a low risk of bias\n'
#  'based on a score that did not include intention to treat as one of the '
#  'risk-of-bias criteria. How-\n'
#  'ever, there were high levels of heterogeneity in the results between the '
#  'trials, bringing into\n'
#  'question the clinical importance of calcium supplementation on BW [15].\n'
#  'Mendelian randomisation (MR) is a method in which genetic variants '
#  'associated with a\n'
#  'modifiable exposure are used as instrumental variables to estimate the '
#  'causal effect of the expo-\n'
#  'sure on an outcome [17]. As genetic variants are fixed at conception and are '
#  'generally not\n'
#  'associated with classical confounders, MR is less susceptible to bias '
#  'resulting from reverse cau-\n'
#  'sation and residual confounding [17]. We have previously performed an MR '
#  'study on the\n'
#  'effects of maternal adiposity related exposures on BW, finding a positive '
#  'effect of body mass\n'
#  'index (BMI) and blood glucose and an inverse causal effect of systolic blood '
#  'pressure on BW\n'
#  '[6]. In that study, there was evidence of a possible positive causal effect '
#  'of 25(OH)D on BW;\n'
#  'however, the CIs were wide and included the null value [6]. A possible '
#  'causal association of\n'
#  'maternal circulating calcium with infant BW was not explored in that study, '
#  'and to the best of\n'
#  'our knowledge, there have been no MR studies of that association. The aim of '
#  'this study was to\n'
#  'use MR to explore whether there are causal effects of maternal circulating '
#  '25(OH)D and cal-\n'
#  'cium on BW and, if so, what the magnitude those effects are. With the '
#  'release of new UK Bio-\n'
#  'bank (UKB) data [18], we have a substantially increased sample size in '
#  'comparison to the\n'
#  'earlier MR study of 25(OH)D, as well as access to more genetic instruments '
#  'for 25(OH)D [19],\n'
#  'both of which will increase statistical power and hence effect estimate '
#  'precision. We comple-\n'
#  'ment our MR analyses by triangulating results with findings from '
#  'instrumental variable analy-\n'
#  'ses applied to RCTs of supplementation with vitamin D or calcium [20].\n'
#  'Methods\n'
#  'The analyses plan was developed by RMF, DAL, WDT, and MCB, prior to any '
#  'analyses begin-\n'
#  'ning. It was acted on by WDT and MCB. The analysis plan has not been '
#  'published but was\n'
#  'informally recorded in meeting notes. We made one change to the overall '
#  'study plans after\n'
#  'completing analyses; we undertook risk-of-bias assessment of the RCTs with a '
#  'focus on factors\n'
#  'that might mean instrumental variable assumptions were violated. This was '
#  'motivated by dif-\n'
#  'ferences in results comparing MR to instrumental variables in RCTs, '
#  'particularly in relation to\n'
#  'the effects of calcium on BW. We made one change to the plan following '
#  'reviewers’ comments;\n'
#  'we undertook two multivariable MR analyses to adjust for potential '
#  'confounders. These were\n'
#  '(1) multivariable MR of the association of 25(OH)D with BW adjusting '
#  '(genetically) for\n'
#  'maternal height and (2) partial multivariable MR of the association of '
#  'calcium with BW adjust-\n'
#  'ing (genetically) for maternal educational level.\n'
#  'The study design and different data sources are summarised in Fig 1, with '
#  'Table 1, S1, S2,\n'
#  'S3 and S4 Text, S1, S2, S3 and S4 Tables, S1, S2 and S3 Figs providing more '
#  'data on each study\n'
#  'that has contributed to this paper. Details of participant consent are '
#  'described in S1 Text. Ethi-\n'
#  'cal approval for data extraction from all of the cohorts used in this study '
#  'was granted from the\n'
#  'appropriate authorities (for more details, see S1 Text). This study is '
#  'reported according to the\n'
#  'Strengthening the Reporting of Observational Studies in Epidemiology '
#  '(STROBE) guideline\n'
#  '(S1 Checklist).\n'
#  'Mendelian randomisation\n'
#  'We used two-sample summary data MR to explore the effect of maternal '
#  'circulating vitamin D\n'
#  '(25[OH]D) and calcium levels on offspring BW [23]. We used (1) summary data '
#  'from pub-\n'
#  'lished genome-wide association (GWA) studies (GWAS) for the associations of '
#  'genetic\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "4 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 3}')
# ('This is the document contentvariants (single-nucleotide polymorphisms '
#  '[SNPs]) with 25(OH)D [19,24] or calcium [25]\n'
#  '(sample 1) and (2) summary data for the associations of SNPs with BW from '
#  'UKB [18] (sam-\n'
#  'ple 2). Summary data from two UK birth cohorts, the Avon Longitudinal Study '
#  'of Parents and\n'
#  'Children (ALSPAC) [26] and Exeter Family Study of Childhood Health (EFSOCH) '
#  '[27], were\n'
#  'generated for use in sensitivity analyses to explore bias due to fetal '
#  'genotype. In all studies, we\n'
#  'excluded participants of non–white European origin (S2 Text describes how '
#  'ethnicity was\n'
#  'defined in each study). Following these exclusions, we included 190,406 '
#  'women from UKB\n'
#  'who had valid data on BW of first child and GWAS data, 4,576 '
#  'mother–offspring pairs from\n'
#  'ALSPAC, and 647 mother–offspring pairs from EFSOCH who all had offspring BW '
#  'and\n'
#  'maternal and offspring GWAS data.\n'
#  'BW and serum 25(OH)D measurement\n'
#  'The UKB is a study of 502,655 participants [28]. Female participants (N = '
#  '273,495) were also\n'
#  'asked to report the BW of their first child. Female participants that '
#  'reported having a multiple\n'
#  'first birth were excluded from our analyses (N = 1,364). A total of 216,839 '
#  'women with a sin-\n'
#  'gleton pregnancy for their first child reported the BW of their first child. '
#  'Values were reported\n'
#  'to the nearest whole pounds and were converted to kilograms by multiplying '
#  'by 0.454 for our\n'
#  'analyses. When women reported the BW of the first child at multiple time '
#  'points (N = 11,353),\n'
#  'we used the mean of all measures after excluding any women with a difference '
#  'of >1 kg\n'
#  'between any two measures (N = 31). We further excluded from the whole sample '
#  'any women\n'
#  'who reported the BW of their first child < 2.2 kg or > 4.6 kg (N = 6,333). '
#  'This was done to\n'
#  'reduce bias from reporting errors and, in relation to those < 2.2 kg, to '
#  'exclude extreme pre-\n'
#  'term births, given that we do not have information on gestational age. BW of '
#  'first child was\n'
#  'Fig 1. Summary of methods and data contributing to this study. ALSPAC, Avon '
#  'Longitudinal Study of Parents and Children; EFSOCH, Exeter\n'
#  'Family Study of Childhood Health; IVW, inverse variance–weighted; MR, '
#  'mendelian randomisation; RCT, randomised controlled trial; SNP, single-\n'
#  'nucleotide polymorphism.\n'
#  'https://doi.org/10.1371/journal.pmed.1002828.g001\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "5 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 4}')
# ('This is the document contentTable 1. Characteristics of the studies used to '
#  'obtain 25(OH)D/calcium SNPs’ (genetic instrumental variables)\n'
#  'effects on offspring birth weight.\n'
#  'Study\n'
#  'Average/Typical Value of Study\n'
#  'Country\n'
#  'UK Biobank\n'
#  'United Kingdom\n'
#  'ALSPAC\n'
#  'United Kingdom\n'
#  'EFSOCH\n'
#  'United Kingdom\n'
#  'Offspring years of birth\n'
#  'UK Biobank\n'
#  '1954–2011\n'
#  'ALSPAC\n'
#  '1991–1993\n'
#  'EFSOCH\n'
#  '2000–2004\n'
#  'Number of participants\n'
#  'UK Biobank\n'
#  '190,406\n'
#  'ALSPAC\n'
#  '4,576\n'
#  'EFSOCH\n'
#  '647\n'
#  'Maternal age, years\n'
#  'UK Biobank\n'
#  '25.9 (5.0)\n'
#  'ALSPAC\n'
#  '29.0 (4.6)\n'
#  'EFSOCH\n'
#  '30.4 (5.2)\n'
#  'Maternal BMI, kg/m2\n'
#  'UK Biobank\n'
#  '27.07 (5.03)\n'
#  'ALSPAC\n'
#  '22.91 (3.72)\n'
#  'EFSOCH\n'
#  '24.03 (4.32)\n'
#  'Maternal height, cm\n'
#  'UK Biobank\n'
#  '162.5 (6.1)\n'
#  'ALSPAC\n'
#  '164.5 (6.7)\n'
#  'EFSOCH\n'
#  '165.0 (6.3)\n'
#  'Birth weight, g\n'
#  'UK Biobank\n'
#  '3,227 (476)\n'
#  'ALSPAC\n'
#  '3,495 (471)\n'
#  'EFSOCH\n'
#  '3,514 (475)\n'
#  'Gestational age, weeks\n'
#  'UK Biobank\n'
#  'NA\n'
#  'ALSPAC\n'
#  '39.8 (1.3)\n'
#  'EFSOCH\n'
#  '40.1 (1.2)\n'
#  'Offspring sex, % male\n'
#  'UK Biobank\n'
#  'NA\n'
#  'ALSPAC\n'
#  '49\n'
#  'EFSOCH\n'
#  '52\n'
#  'Maternal systolic blood pressure, mmHg\n'
#  'UK Biobank\n'
#  '141 (24)\n'
#  'ALSPAC\n'
#  '133 (13)\n'
#  'EFSOCH\n'
#  'NA\n'
#  'Mothers smoking, %a\n'
#  'UK Biobank\n'
#  '12\n'
#  'ALSPAC\n'
#  '15\n'
#  'EFSOCH\n'
#  '14\n'
#  'Townsend deprivation indexb\n'
#  'UK Biobank\n'
#  '−1.66 (2.86)\n'
#  'ALSPAC\n'
#  'NA\n'
#  'EFSOCH\n'
#  '0.23 (3.29)\n'
#  'Educational attainment: mothers with a university degree, %\n'
#  'UK Biobank\n'
#  '47\n'
#  'ALSPAC\n'
#  '14\n'
#  'EFSOCH\n'
#  'NA\n'
#  'Western dietc (SD)\n'
#  'UK Biobank\n'
#  '−0.087 (0.98)\n'
#  'ALSPAC\n'
#  'NA\n'
#  'EFSOCH\n'
#  'NA\n'
#  '(Continued)\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "6 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 5}')
# ('This is the document contentregressed against the women’s reported age at '
#  'first birth and UKB assessment centre location\n'
#  'to reduce heterogeneity in reporting bias by these characteristics. '
#  'Residuals from that regres-\n'
#  'sion model were then standardised to a mean of 0 and an SD of 1, with the '
#  'standardised resid-\n'
#  'uals being used in all analyses and final results converted back to grams. '
#  'The analyses were\n'
#  'done on standardised residuals to reduce the amount of computing power '
#  'needed when doing\n'
#  'the initial GWA analyses, and so the summary GWAS data that we used for our '
#  'main analyses\n'
#  'were already in this standardised format. UKB participants’ (women and men) '
#  'reports of their\n'
#  'own BWs were used in sensitivity analyses described below, and similar '
#  'methods of exclusion\n'
#  'and use of standardised (on age at assessment and centre) residuals, with '
#  'conversion of results\n'
#  'back to grams, were used for own BW (see S3 Text for further details).\n'
#  'In ALSPAC and EFSOCH, BW was extracted (in grams) from obstetric clinical '
#  'records at\n'
#  'the time of birth, which occurred between 1991 and 1992 (mean [SD] age of '
#  'mothers 29 [4.6]\n'
#  'years) in ALSPAC [26] and between 2000 and 2004 (mean age of mothers 30.4 '
#  '[5.2] years) in\n'
#  'EFSOCH [27].\n'
#  'The GWAS of 25(OH)D and calcium that we have used in our MR analyses were '
#  'under-\n'
#  'taken on adult European-origin (nonpregnant) women and men. Our MR analyses '
#  'assume\n'
#  'that the magnitude of gene instrument variable-25(OH)D (or calcium) '
#  'association from those\n'
#  'studies are the same in women during pregnancy. We were able to test this '
#  'for 25(OH)D in\n'
#  'ALSPAC, in which 25(OH)D was measured during pregnancy in mothers, using '
#  'methods that\n'
#  'have previously been reported [29] (see S4 Text). Neither 25(OH)D nor '
#  'calcium were mea-\n'
#  'sured during pregnancy in UKB or EFSOCH; calcium was not measured in '
#  'ALSPAC.\n'
#  'Genotyping\n'
#  'For UKB, we analysed data from the May 2017 release of imputed genetic data, '
#  'which have\n'
#  'been extensively described elsewhere [30]. Given the reported technical '
#  'error with non-HRC\n'
#  'imputed variants [31], we focused exclusively on the set of approximately 40 '
#  'million imputed\n'
#  'variants from the HRC reference panel.\n'
#  'Table 1. (Continued)\n'
#  'Study\n'
#  'Average/Typical Value of Study\n'
#  'Age of assessment for age of first birth, years\n'
#  'UK Biobank\n'
#  '58.0 (7.8)\n'
#  'ALSPAC\n'
#  'NA\n'
#  'EFSOCH\n'
#  'NA\n'
#  'aIn ALSPAC and EFSOCH, this is the percentage of women who smoked during '
#  'pregnancy; for UK Biobank, it is the\n'
#  'percentage of women who smoke.\n'
#  'bAn area deprivation index that takes summary data on deprivation measures '
#  'from the census for a defined small\n'
#  'geographical area (percentage of households without a motor vehicle, '
#  'percentage of households with more than one\n'
#  'person per room, percentage of households not owner-occupied, and percentage '
#  'of residents who are unemployed),\n'
#  'converts them to SD scores across all areas of the UK, and then sums them to '
#  'give a relative area deprivation value,\n'
#  'such that a higher score indicates greater deprivation for the area compared '
#  'to the UK as a whole [21]; in UK\n'
#  'Biobank, these reflect adult area of residence deprivation based on the '
#  'postcode provided by the participants at their\n'
#  'baseline assessment (aged 40–60 years).\n'
#  'cWestern diet is a principal component of variation in reported diet in UK '
#  'Biobank. Variation in diet was measured\n'
#  'using a dietary questionnaire [22].\n'
#  'Abbreviations: ALSPAC, Avon Longitudinal Study of Parents and Children; BMI, '
#  'body mass index; EFSOCH, Exeter\n'
#  'Family Study of Childhood Health.\n'
#  'https://doi.org/10.1371/journal.pmed.1002828.t001\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "7 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 6}')
# ('This is the document contentTo account for population structure and '
#  'relatedness, a linear mixed model implemented in\n'
#  'BOLT-LMM v2.3 [32] was used to perform genome-wide association (GWA) '
#  'analysis of BW\n'
#  'in the UKB sample. Only autosomal SNPs that were common (MAF > 1%), in Hardy '
#  'Wein-\n'
#  'berg equilibrium (HWE; p-value > 1 × 10−6), passed QC in all 106 batches, '
#  'and were present\n'
#  'on both genotyping arrays were included in the genetic relationship matrix '
#  '(GRM). For the\n'
#  'GWA analyses of BW of the first child (i.e., using the maternal genotype), '
#  'the genotyping\n'
#  'array and genotyping release (interim versus full) were included as '
#  'covariates in the regression\n'
#  'model. For the GWAS of participants’ own BW (see below under ‘Exploring '
#  'violation of MR\n'
#  'assumptions’ for the rationale behind these analyses), genotyping array, age '
#  'at baseline, and\n'
#  'sex were adjusted for in all models.\n'
#  'In both ALSPAC and EFSOCH, the SNPs used in this study (see below) were '
#  'taken from\n'
#  'genome-wide imputed data that had been completed for both the mothers and '
#  'their offspring\n'
#  '(fetal genotype). In ALSPAC, maternal data were obtained from the Illumina '
#  '610 Quad Array,\n'
#  'and fetal data were obtained from the Illumina 550 Quad Array. In EFSOCH, '
#  'maternal and\n'
#  'fetal data were obtained from the Illumina Infinium HumanCoreExome-24. For '
#  'both\n'
#  'ALSPAC and EFSOCH, genotype data were imputed against Haplotype Reference '
#  'Consortium\n'
#  'HRC v1.1 reference panel after quality control (MAF > 1%, HWE > 1 × 10−6, '
#  'sex mismatch,\n'
#  'kinship errors, and 4.56 SD from the cluster mean of any subpopulations '
#  'cluster) [26,33].\n'
#  'SNP selection and summary data for SNP–25(OH)D and SNP–calcium\n'
#  'associations\n'
#  'We searched for the largest well-conducted GWAS to identify genetic variants '
#  '(SNPs) that\n'
#  'could be used as instrumental variables for circulating 25(OH)D and calcium '
#  'and to obtain\n'
#  'summary data of genetic instrumental variable (SNP) associations with '
#  '25(OH)D and calcium\n'
#  'for use in our two-sample MR.\n'
#  'For 25(OH)D, we used summary association results for SNPs identified in two '
#  'GWAS\n'
#  '[19,24], with the largest of these including 79,366 participants from 31 '
#  'studies in discovery\n'
#  'analyses and 42,757 participants from two studies in replication analyses. '
#  'In our main analyses,\n'
#  'we used seven SNPs, which were not in linkage disequilibrium, from either of '
#  'the GWAS that\n'
#  'had a p-value of 5 × 10−8 in discovery analyses and were replicated. Two of '
#  'the SNPs discov-\n'
#  'ered in the largest GWAS (rs3755967 and rs17216707) were different from, but '
#  'in the same\n'
#  'loci as, two SNPs identified in an earlier, more commonly used GWAS '
#  '(rs2282679 and\n'
#  'rs6013897, respectively) [34] that have been commonly used as instruments of '
#  '25(OH)D in\n'
#  'previous MR analyses. We measured linkage disequilibrium between these SNPs '
#  'in white\n'
#  'Europeans (CEU) using LDLink [35,36] and found that both were >0.5, '
#  'suggesting the SNPs\n'
#  'in each pair are tagging the same variant. In additional analyses, we '
#  'separately conducted two\n'
#  'analyses with genetic instruments hypothesised to be involved in 25(OH)D '
#  'synthesis (three\n'
#  'SNPs) and 25(OH)D metabolism (two SNPs) [37].\n'
#  'For calcium, we used summary association results for SNPs identified in a '
#  'GWAS of 39,400\n'
#  'participants [25] from 19 studies in discovery analyses and 21,875 '
#  'participants from 11 studies\n'
#  'as replication. We used seven SNPs, which were not in linkage '
#  'disequilibrium, that were asso-\n'
#  'ciated with calcium levels at a p-value of 5 × 10−8 in discovery analysis '
#  'and were replicated.\n'
#  'Further details of the 25(OH)D and calcium GWAS are provided in S1 Table, '
#  'and a list of\n'
#  'the SNPs used in our MR analyses, together with their allele frequencies and '
#  'per-allele associa-\n'
#  'tions, for 25(OH)D and calcium are provided in S2 Table.\n'
#  'For UKB, the summary results of associations between SNPs and first-child BW '
#  '(maternal\n'
#  'genotype) or own BW (own genotype) were extracted from the GWAS results (see '
#  'above for\n'
#  'details on how each GWAS was conducted). For ALSPAC and EFSOCH, '
#  'individual-level SNP\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "8 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 7}')
# ('This is the document contentdata were extracted and summary data were '
#  'generated using multivariate linear regression of\n'
#  'the SNPs against BW (adjusting for gestational age and the child’s sex).\n'
#  'To make sure that the outcome data (BW) and exposure data (25[OH]D and '
#  'calcium) were\n'
#  'comparable, the SNPs’ effects were harmonised to the 25(OH)D/calcium-raising '
#  'alleles using\n'
#  'procedures that have previously been described [38].\n'
#  'Statistical analysis\n'
#  'The main and sensitivity two-sample MR methods are summarised in Table 2. In '
#  'all analyses,\n'
#  'we estimated the effect of a 10% increase in 25(OH)D on BW in grams and the '
#  'effect of 1 SD\n'
#  'increase in calcium on BW in grams, these units reflecting the units of '
#  '25(OH)D and calcium\n'
#  'used in the published GWAS. The value of a 10% increase in 25(OH)D will vary '
#  'depending on\n'
#  'the ‘starting point’. In the gestational measures of 25(OH)D in ALSPAC, the '
#  'median level of\n'
#  '25(OH)D is 61.8 nmol/l, the 25th percentile is 46.1 nmol/l, and the 75th '
#  'percentile is 81.6\n'
#  'nmol/l; this makes a 10% increase from these points equivalent to 6.2 '
#  'nmol/l, 4.6 nmol/l, and\n'
#  '8.2 nmol/l, respectively. The accepted range of calcium in a healthy '
#  'population is between 8.5\n'
#  'mg/dl and 10.5 mg/dl [39], and dividing that range by four, we estimated '
#  'that the SD of cal-\n'
#  'cium is 0.5 mg/dl (approximately 0.3 mmol/l).\n'
#  'The main effects were calculated in all three studies (UKB, ALSPAC, and '
#  'EFSOCH) using\n'
#  'two methods: fixed-effect meta-analysis of Wald ratios [40] of the seven '
#  'SNPs for 25(OH)D or\n'
#  'the seven SNPs for calcium and the inverse variance–weighted (IVW) '
#  'instrumental variable\n'
#  'method [41] (Table 2).\n'
#  'Wald ratios were calculated by dividing each SNP’s effect on BW by the same '
#  'SNP’s effect\n'
#  'on the exposure (25[OH]D or calcium). Standard errors were calculated by '
#  'dividing the stan-\n'
#  'dard error of the SNP’s effect on BW by each SNP’s effect on the exposure. '
#  'The ratios for each\n'
#  'SNP were then pooled using fixed-effect meta-analysis. I2 and leave-one-out '
#  'analysis were\n'
#  'used to explore between SNP heterogeneity in their MR results (which, if '
#  'present, may be due\n'
#  'to one or more of the SNPs being an invalid instrumental variable) [43].\n'
#  'For the IVW analysis, linear regression of the weighted (by inverse of their '
#  'variance) SNPs’\n'
#  'associations with BW against the SNPs’ association with maternal circulating '
#  '25(OH)D or\n'
#  'Table 2. Summary of the four methods used for MR analysis.\n'
#  'Name of\n'
#  'Method\n'
#  'Wald Ratio (Meta-analysis) [40]\n'
#  'Inverse Variance–Weighted [41]\n'
#  'MR-Egger [41]\n'
#  'Weighted Median [42]\n'
#  'Assumption\n'
#  'There is no unbalanced horizontal\n'
#  'pleiotropy.\n'
#  'There is no unbalanced horizontal\n'
#  'pleiotropy.\n'
#  'That the effect of the genetic\n'
#  'instrument is not correlated\n'
#  'with any pleiotropic effect of\n'
#  'the instrument on the\n'
#  'outcome.\n'
#  'Less than 50% of the weight in the\n'
#  'analyses comes from invalid\n'
#  'instruments.\n'
#  'Equation\n'
#  'Wald Ratio ¼\n'
#  'byjz\n'
#  'bxjz\n'
#  'bIVW¼\n'
#  'PJ\n'
#  'j¼1 E2\n'
#  'j se\x00 2\n'
#  'j\n'
#  'bj\n'
#  'PJ\n'
#  'j¼1 E2\n'
#  'j se\x00 2\n'
#  'j\n'
#  'bMR ¼\n'
#  'rj\x00 b0\n'
#  'Ej\n'
#  'rj ¼ 100ðSj \x00wj\n'
#  '2Þ\n'
#  'Notes on\n'
#  'equation\n'
#  'βy|z is the SNP’s effect on the outcome,\n'
#  'and βx|z is the SNP’s effect on the\n'
#  'exposure. Wald ratios for each SNP\n'
#  'were pooled using fixed-effect meta-\n'
#  'analysis with inverse-variance weights.\n'
#  'βj is the ratio method estimate for each\n'
#  'genetic instrument, σej−2 is the\n'
#  'standard error of the genetic variants\n'
#  'effect on outcome, and Ej2 is the\n'
#  'genetic instruments effect on the\n'
#  'exposure.\n'
#  'β0 is the intercept, Ej is the\n'
#  'genetic instruments effect on\n'
#  'the exposure, and ρj is the\n'
#  'genetic instruments effect on\n'
#  'the outcome.\n'
#  'Multiple ratio estimates, or βj, are\n'
#  'calculated, and the median percentile\n'
#  'value is chosen. Each percentile value\n'
#  'is weighted. Sj is the sum of the\n'
#  'weights up to the given genetic\n'
#  'instrument, ρj is the percentile value,\n'
#  'and wj is the weight given to the\n'
#  'genetic instrument.\n'
#  'Abbreviations: MR, mendelian randomisation; SNP, single-nucleotide '
#  'polymorphism.\n'
#  'https://doi.org/10.1371/journal.pmed.1002828.t002\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "9 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
# ...
#  '19.\n'
#  'Jiang X, O’Reilly PF, Aschard H, Hsu YH, Richards JB, Dupuis J, et al. '
#  'Genome-wide association study\n'
#  'in 79,366 European-ancestry individuals informs the genetic architecture of '
#  '25-hydroxyvitamin D levels.\n'
#  'Nature communications. 2018; 9(1):260. Epub 2018/01/19. '
#  'https://doi.org/10.1038/s41467-017-02662-2\n'
#  'PMID: 29343764\n'
#  '20.\n'
#  'Lawlor DA, Tilling K, Davey Smith G. Triangulation in aetiological '
#  'epidemiology. Int J Epidemiol. 2016;\n'
#  '45(6):1866–86. Epub 2017/01/22. https://doi.org/10.1093/ije/dyw314 PMID: '
#  '28108528\n'
#  '21.\n'
#  'Townsend P, Phillimore P, Beattie A. Health and Deprivation: Inequality and '
#  'the North. London: Rout-\n'
#  'ledge; 1988.\n'
#  '22.\n'
#  'Bradbury KE, Young HJ, Guo W, Key TJ. Dietary assessment in UK Biobank: an '
#  'evaluation of the per-\n'
#  'formance of the touchscreen dietary questionnaire. Journal of Nutritional '
#  'Science. 2018; 7:e6. https://\n'
#  'doi.org/10.1017/jns.2017.66 PMID: 29430297\n'
#  '23.\n'
#  'Lawlor DA. Commentary: Two-sample Mendelian randomization: opportunities and '
#  'challenges. Interna-\n'
#  'tional Journal of Epidemiology. 2016; 45(3):908–15. '
#  'https://doi.org/10.1093/ije/dyw127 PMID:\n'
#  '27427429\n'
#  '24.\n'
#  'Manousaki D, Dudding T, Haworth S, Hsu Y-H, Liu C-T, Medina-Go´mez C, et al. '
#  'Low-Frequency Syn-\n'
#  'onymous Coding Variation in CYP2R1 Has Large Effects on Vitamin D Levels and '
#  'Risk of Multiple Scle-\n'
#  'rosis. The American Journal of Human Genetics. 2017; 101(2):227–38. '
#  'Available from: https://doi.org/\n'
#  '10.1016/j.ajhg.2017.06.014. PMID: 28757204\n'
#  '25.\n'
#  'O’Seaghdha CM, Wu H, Yang Q, Kapur K, Guessous I, Zuber AM, et al. '
#  'Meta-Analysis of Genome-\n'
#  'Wide Association Studies Identifies Six New Loci for Serum Calcium '
#  'Concentrations. PLoS Genet.\n'
#  '2013; 9(9):e1003796. https://doi.org/10.1371/journal.pgen.1003796 PMID: '
#  '24068962\n'
#  '26.\n'
#  'Fraser A, Macdonald-Wallis C, Tilling K, Boyd A, Golding J, Davey Smith G, '
#  'et al. Cohort Profile: The\n'
#  'Avon Longitudinal Study of Parents and Children: ALSPAC mothers cohort. '
#  'International Journal of Epi-\n'
#  'demiology. 2013; 42(1):97–110. https://doi.org/10.1093/ije/dys066 PMID: '
#  '22507742\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "22 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 21}')
# ('This is the document content27.\n'
#  'Knight B, Shields BM, Hattersley AT. The Exeter Family Study of Childhood '
#  'Health (EFSOCH): study\n'
#  'protocol and methodology. Paediatric and Perinatal Epidemiology. 2006; '
#  '20(2):172–9. https://doi.org/\n'
#  '10.1111/j.1365-3016.2006.00701.x PMID: 16466435\n'
#  '28.\n'
#  'Bycroft C, Freeman C, Petkova D, Band G, Elliott LT, Sharp K, et al. The UK '
#  'Biobank resource with\n'
#  'deep phenotyping and genomic data. Nature. 2018; 562(7726):203–9. '
#  'https://doi.org/10.1038/s41586-\n'
#  '018-0579-z PMID: 30305743\n'
#  '29.\n'
#  'Lawlor DA, Wills AK, Fraser A, Sayers A, Fraser WD, Tobias JH. Association '
#  'of maternal vitamin D sta-\n'
#  'tus during pregnancy with bone-mineral content in offspring: a prospective '
#  'cohort study. Lancet. 2013;\n'
#  '381(9884):2176–83. https://doi.org/10.1016/S0140-6736(12)62203-X PMID: '
#  '23518316\n'
#  '30.\n'
#  'Bycroft C, Freeman C, Petkova D, Band G, Elliott LT, Sharp K, et al. '
#  'Genome-wide genetic data on\n'
#  '~500,000 UK Biobank participants. bioRxiv. 2017. '
#  'https://doi.org/10.1101/166298\n'
#  '31.\n'
#  'UK Biobank, the Access Team. Important note about imputed genetics data '
#  'biobank. 2017 [cited 2019\n'
#  'May 2]. '
#  'http://www.ukbiobank.ac.uk/2017/07/important-note-about-imputed-genetics-data/.\n'
#  '32.\n'
#  'Loh P-R, Tucker G, Bulik-Sullivan BK, Vilhja´lmsson BJ, Finucane HK, Salem '
#  'RM, et al. Efficient Bayes-\n'
#  'ian mixed model analysis increases association power in large cohorts. '
#  'Nature genetics. 2015; 47\n'
#  '(3):284–90. https://doi.org/10.1038/ng.3190 PMID: 25642633\n'
#  '33.\n'
#  'Boyd A, Golding J, Macleod J, Lawlor DA, Fraser A, Henderson J, et al. '
#  'Cohort Profile: The ‘Children of\n'
#  'the 90s’—the index offspring of the Avon Longitudinal Study of Parents and '
#  'Children. International Jour-\n'
#  'nal of Epidemiology. 2013; 42(1):111–27. https://doi.org/10.1093/ije/dys064 '
#  'PMID: 22507743\n'
#  '34.\n'
#  'Wang TJ, Zhang F, Richards JB, Kestenbaum B, van Meurs JB, Berry D, et al. '
#  'Common genetic deter-\n'
#  'minants of vitamin D insufficiency: a genome-wide association study. Lancet. '
#  '2010; 376(9736):180–8.\n'
#  'https://doi.org/10.1016/S0140-6736(10)60588-0 PMID: 20541252\n'
#  '35.\n'
#  'Machiela MJ, Chanock SJ. LDlink: a web-based application for exploring '
#  'population-specific haplotype\n'
#  'structure and linking correlated alleles of possible functional variants. '
#  'Bioinformatics. 2015; 31\n'
#  '(21):3555–7. Epub 2015/07/04. https://doi.org/10.1093/bioinformatics/btv402 '
#  'PMID: 26139635\n'
#  '36.\n'
#  'Machiela MJ, Chanock SJ. LDassoc: an online tool for interactively exploring '
#  'genome-wide association\n'
#  'study results and prioritizing variants for functional investigation. '
#  'Bioinformatics. 2018; 34(5):887–9.\n'
#  'Epub 2017/10/03. https://doi.org/10.1093/bioinformatics/btx561 PMID: '
#  '28968746\n'
#  '37.\n'
#  'Vimaleswaran KS, Berry DJ, Lu C, Tikkanen E, Pilz S, Hiraki LT, et al. '
#  'Causal Relationship between\n'
#  'Obesity and Vitamin D Status: Bi-Directional Mendelian Randomization '
#  'Analysis of Multiple Cohorts.\n'
#  'PLoS Med. 2013; 10(2):e1001383. https://doi.org/10.1371/journal.pmed.1001383 '
#  'PMID: 23393431\n'
#  '38.\n'
#  'Hartwig FP, Davies NM, Hemani G, Davey Smith G. Two-sample Mendelian '
#  'randomization: avoiding\n'
#  'the downsides of a powerful, widely applicable but potentially fallible '
#  'technique. International Journal of\n'
#  'Epidemiology. 2016; 45(6):1717–26. https://doi.org/10.1093/ije/dyx028 PMID: '
#  '28338968\n'
#  '39.\n'
#  'Goldstein D. Serum Calcium. In: Walker HK, Hall WD, Hurst JW, editors. '
#  'Clinical Methods: The History,\n'
#  'Physical, and Laboratory Examinations [Internet]. 3rd ed. Boston: '
#  'Butterworths; 1990. https://www.\n'
#  'ncbi.nlm.nih.gov/books/NBK250/. [cited 2019 May 2]\n'
#  '40.\n'
#  'Stephen B, Dylan SS, Simon GT. A review of instrumental variable estimators '
#  'for Mendelian randomiza-\n'
#  'tion. Statistical Methods in Medical Research. 2015; 26(5):2333–55. '
#  'https://doi.org/10.1177/\n'
#  '0962280215597579 PMID: 26282889\n'
#  '41.\n'
#  'Bowden J, Davey Smith G, Burgess S. Mendelian randomization with invalid '
#  'instruments: effect estima-\n'
#  'tion and bias detection through Egger regression. International Journal of '
#  'Epidemiology. 2015; 44\n'
#  '(2):512–25. https://doi.org/10.1093/ije/dyv080 PMID: 26050253\n'
#  '42.\n'
#  'Bowden J, Davey Smith G, Haycock PC, Burgess S. Consistent Estimation in '
#  'Mendelian Randomiza-\n'
#  'tion with Some Invalid Instruments Using a Weighted Median Estimator. '
#  'Genetic Epidemiology. 2016;\n'
#  '40(4):304–14. https://doi.org/10.1002/gepi.21965 PMID: 27061298\n'
#  '43.\n'
#  'Steichen T, Statistical Software Components, Boston College Department of '
#  'Economics. METANINF:\n'
#  'Stata Module to Evaluate Influence of a Single Study in Meta-analysis '
#  'Estimation. 2001. https://\n'
#  'econpapers.repec.org/software/bocbocode/s419201.htm. [cited 2019 May 31]\n'
#  '44.\n'
#  'Lawlor D, Richmond R, Warrington N, McMahon G, Davey Smith G, Bowden J, et '
#  'al. Using Mendelian\n'
#  'randomization to determine causal effects of maternal pregnancy '
#  '(intrauterine) exposures on offspring\n'
#  'outcomes: Sources of bias and methods for assessing them. Wellcome open '
#  'research. 2017; 2:11.\n'
#  'https://doi.org/10.12688/wellcomeopenres.10567.1 PMID: 28405635\n'
#  '45.\n'
#  'Greenland S. An introduction to instrumental variables for epidemiologists. '
#  'International Journal of Epi-\n'
#  'demiology. 2000; 29(4):722–9. https://doi.org/10.1093/ije/29.4.722 PMID: '
#  '10922351\n'
#  '46.\n'
#  'Boggess KA, Samuel L, Schmucker BC, Waters J, Easterling TR. A randomized '
#  'controlled trial of the\n'
#  'effect of third-trimester calcium supplementation on maternal hemodynamic '
#  'function. Obstetrics &\n'
#  'Gynecology. 1997; 90(2):157–61. Available from: '
#  'https://doi.org/10.1016/S0029-7844(97)00248-2.\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "23 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 22}')
# ('This is the document content47.\n'
#  'Sanderson E, Davey Smith G, Windmeijer F, Bowden J. An examination of '
#  'multivariable Mendelian ran-\n'
#  'domization in the single-sample and two-sample summary data settings. Int J '
#  'Epidemiol. 2018:dyy262.\n'
#  'Epub 2018/12/12. https://doi.org/10.1093/ije/dyy262 PMID: 30535378\n'
#  '48.\n'
#  'Cooper C, Harvey NC, Bishop NJ, Kennedy S, Papageorghiou AT, Schoenmakers I, '
#  'et al. Maternal\n'
#  'gestational vitamin D supplementation and offspring bone health (MAVIDOS): a '
#  'multicentre, double-\n'
#  'blind, randomised placebo-controlled trial. The Lancet Diabetes & '
#  'Endocrinology. 2016; 4(5):393–402.\n'
#  'Available from: http://dx.doi.org/10.1016/S2213-8587(16)00044-9.\n'
#  '49.\n'
#  'Magnus MC, Miliku K, Bauer A, Engel SM, Felix JF, Jaddoe VWV, et al. Vitamin '
#  'D and risk of pregnancy\n'
#  'related hypertensive disorders: mendelian randomisation study. BMJ. 2018; '
#  '361:k2167. https://doi.org/\n'
#  '10.1136/bmj.k2167 PMID: 29925546\n'
#  '50.\n'
#  'Lips P. Relative Value of 25(OH)D and 1,25(OH)2D Measurements. Journal of '
#  'Bone and Mineral\n'
#  'Research. 2007; 22(11):1668–71. https://doi.org/10.1359/jbmr.070716 PMID: '
#  '17645404\n'
#  '51.\n'
#  'Pu F, Chen N, Xue S. Calcium intake, calcium homeostasis and health. Food '
#  'Science and Human Well-\n'
#  'ness. 2016; 5(1):8–16. Available from: '
#  'https://doi.org/10.1016/j.fshw.2016.01.001.\n'
#  '52.\n'
#  'Bi M, Kao WHL, Boerwinkle E, Hoogeveen RC, Rasmussen-Torvik LJ, Astor BC, et '
#  'al. Association of\n'
#  'rs780094 in GCKR with metabolic traits and incident diabetes and '
#  'cardiovascular disease: the ARIC\n'
#  'Study. PLoS ONE. 2010; 5(7):e11690-e. '
#  'https://doi.org/10.1371/journal.pone.0011690 PMID:\n'
#  '20661421\n'
#  '53.\n'
#  'Goodfellow L, Cooper C, Harvey N. Regulation of Placental Calcium Transport '
#  'and Offspring Bone\n'
#  'Health. Frontiers in Endocrinology. 2011; 2(3). '
#  'https://doi.org/10.3389/fendo.2011.00003 PMID:\n'
#  '22649358\n'
#  '54.\n'
#  'Kovaks CS. Calcium and Phosphate Metabolism and Related Disorders During '
#  'Pregnancy and Lacta-\n'
#  'tion. In: Feingold KR, Anawalt B, Boyce A, Chrousos G, Dungan K, Grossman A, '
#  'Hershman JH, Kaltsas\n'
#  'G, Koch C, Kopp P, Korbonits M, McLachlan R, Morley JE, New M, Perreault L, '
#  'Purnell J, Rebar R,\n'
#  'Singer F, Trence DL, Vinik A, Wilson DP, editors. Endotext [Internet]. South '
#  'Dartmouth, MA: MDText.\n'
#  'com, Inc.; 2000. https://www.ncbi.nlm.nih.gov/books/NBK279173/. [cited 2019 '
#  'May 2]\n'
#  '55.\n'
#  'Kapur K, Johnson T, Beckmann ND, Sehmi J, Tanaka T, Kutalik Z, et al. '
#  'Genome-wide meta-analysis\n'
#  'for serum calcium identifies significantly associated SNPs near the '
#  'calcium-sensing receptor (CASR)\n'
#  'gene. PLoS Genet. 2010; 6(7):e1001035. '
#  'https://doi.org/10.1371/journal.pgen.1001035 PMID:\n'
#  '20661308\n'
#  '56.\n'
#  'Fry A, Littlejohns TJ, Sudlow C, Doherty N, Adamska L, Sprosen T, et al. '
#  'Comparison of Sociodemo-\n'
#  'graphic and Health-Related Characteristics of UK Biobank Participants With '
#  'Those of the General Pop-\n'
#  'ulation. American journal of epidemiology. 2017; 186(9):1026–34. Epub '
#  '2017/06/24. https://doi.org/10.\n'
#  '1093/aje/kwx246 PMID: 28641372\n'
#  '57.\n'
#  'Munafo MR, Tilling K, Taylor AE, Evans DM, Davey Smith G. Collider scope: '
#  'when selection bias can\n'
#  'substantially influence observed associations. Int J Epidemiol. 2018; '
#  '47(1):226–35. Epub 2017/10/19.\n'
#  'https://doi.org/10.1093/ije/dyx206 PMID: 29040562\n'
#  '58.\n'
#  'Sallis H, Taylor AE, Munafò MR, Stergiakouli E, Euesden J, Davies NM, et al. '
#  'Exploring the association\n'
#  'of genetic factors with participation in the Avon Longitudinal Study of '
#  'Parents and Children. International\n'
#  'Journal of Epidemiology. 2018; 47(4):1207–16. '
#  'https://doi.org/10.1093/ije/dyy060 PMID: 29800128\n'
#  '59.\n'
#  'Warrington NM, Beaumont RN, Horikoshi M, Day FR, Helgeland Ø, Laurin C, et '
#  'al. Maternal and fetal\n'
#  'genetic effects on birth weight and their relevance to cardio-metabolic risk '
#  'factors. Nature genetics.\n'
#  '2019; 51(5):804–814. https://doi.org/10.1038/s41588-019-0403-1 PMID: '
#  '31043758\n'
#  '60.\n'
#  'Roth DE, Morris SK, Zlotkin S, Gernand AD, Ahmed T, Shanta SS, et al. '
#  'Vitamin D Supplementation in\n'
#  'Pregnancy and Lactation and Infant Growth. New England Journal of Medicine. '
#  '2018; 379(6):535–46.\n'
#  'https://doi.org/10.1056/NEJMoa1800927 PMID: 30089075\n'
#  'Association of maternal circulating 25(OH)D and calcium on birth weight\n'
#  'PLOS Medicine | https://doi.org/10.1371/journal.pmed.1002828\n'
#  'June 18, 2019\n'
#  "24 / 24 and this is the metadata{'producer': 'PDFlib+PDI 9.0.6 (C++/Win64); "
#  "modified using iTextSharp™ 5.5.3 ©2000-2014 iText Group NV (AGPL-version)', "
#  "'creator': 'Arbortext Advanced Print Publisher 11.0.3521/W Unicode-x64', "
#  "'creationdate': '2019-06-08T08:06:07+05:30', 'source': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'file_path': "
#  "'../Data/Raw/vitDandCaonbirthweightMRvsRCT.pdf', 'total_pages': 24, "
#  "'format': 'PDF 1.6', 'title': 'Association of maternal circulating 25(OH)D "
#  "and calcium with birth weight: A mendelian randomisation analysis', "
#  "'author': 'William D. Thompson, Jessica Tyrrell, Maria-Carolina Borges, "
#  'Robin N. Beaumont, Bridget A. Knight, Andrew R. Wood, Susan M. Ring, Andrew '
#  "T. Hattersley, Rachel M. Freathy, Debbie A. Lawlor', 'subject': '', "
#  "'keywords': '', 'moddate': '2019-06-08T08:07:09+05:30', 'trapped': '', "
#  '\'modDate\': "D:20190608080709+05\'30\'", \'creationDate\': '
#  '"D:20190608080607+05\'30\'", \'page\': 23}')

# %% [markdown]
# # 2. Split text into chunks

# %%
# Split text into chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
docs = text_splitter.split_documents(documents)

# %% [markdown]
# # 3. Create embeddings and store in vector DB

# %%
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS

embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_documents(docs,embeddings)

# %% [markdown]
# # 4. Create a Retriever and LLM chain

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model_name='gpt-4-turbo',openai_api_key=api_KEY)
retriever = vectorstore.as_retriever()
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type='stuff'
)

# %% [markdown]
# # 5. Query the pdf

# %%
query = "What is the aim of this study"
result = qa_chain.invoke(query)
pprint.pp(result)
# Out:
# {'query': 'What is the aim of this study',
#  'result': 'The aim of the study is to explore whether there are causal '
#            'effects of maternal circulating 25-hydroxyvitamin D (25(OH)D) and '
#            'calcium on birth weight (BW) and to determine the magnitude of '
#            'those effects. The study employs Mendelian Randomization (MR) and '
#            'triangulates these results with findings from instrumental '
#            'variable analyses applied to randomized controlled trials (RCTs) '
#            'of vitamin D or calcium supplementation. This approach aims to '
#            'provide a more accurate assessment of the causal relationships by '
#            'comparing results from different methodological approaches that '
#            'have unique potential sources of bias.'}
